# %% [markdown]
# # Cleaning and F.E.

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smfm
import patsy
import pprint
import pickle
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from math import sqrt
from sklearn import ensemble

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV, LogisticRegression
from sklearn.metrics import r2_score, explained_variance_score
from sklearn.impute import SimpleImputer
from sklearn.inspection import permutation_importance
from sklearn.compose import ColumnTransformer
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.naive_bayes import BernoulliNB, MultinomialNB, GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier, AdaBoostClassifier, BaggingRegressor
from sklearn.neighbors import KNeighborsClassifier
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.feature_selection import SelectFromModel, RFE, SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler
from lightgbm import LGBMClassifier

import xgboost as xgb
import uuid 
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.float_format', '{:.2f}'.format)
np.set_printoptions(suppress=True)

# %%
df = pd.read_csv("./data/traffic_pop_data.csv")

# %% [markdown]
# ##### Binning

# %%
df_prune = df.copy()

# %%
def Mon(x):
    return x.split(" ")[0].split('-')[1]
def Day(x):
    return x.split(" ")[0].split('-')[2]
def Hour(x):
    return x.split(" ")[1].split(':')[0]
def Minute(x):
    return x.split(" ")[1].split(':')[1]

# %%
df_prune['StartMonth'] = df_prune['StartTime(UTC)'].apply(lambda x: Mon(x)).astype(int)
df_prune['StartDay'] = df_prune['StartTime(UTC)'].apply(lambda x: Day(x)).astype(int)
df_prune['StartHour'] = df_prune['StartTime(UTC)'].apply(lambda x: Hour(x)).astype(int)
df_prune['StartMinute'] = df_prune['StartTime(UTC)'].apply(lambda x: Minute(x)).astype(int)

# %%
df_prune['StartTime(UTC)'] = pd.to_datetime(df_prune['StartTime(UTC)'])

def get_dayofweek(x):
    return x.dayofweek
df_prune['DayOfWeek'] = df_prune['StartTime(UTC)'].apply(lambda x: get_dayofweek(x)).astype(int)

# %%
df_prune.drop('StartTime(UTC)', inplace=True, axis = 1)

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
df_prune['County'] = le.fit_transform(df_prune['County'])

# %%
# (month:label) --- (1-3 : 0), (4-6 : 1), (7-9 : 2), (10-12 : 3)
df_prune['Season'] = np.where((df_prune['StartMonth']<=3), 0, 
                                  np.where((df_prune['StartMonth']>3) & (df_prune['StartMonth']<=6), 1,
                                          np.where((df_prune['StartMonth']>6) & (df_prune['StartMonth']<=9), 2, 3))
                                  )

# %%
# (day:label) --- (1-7 : 0), (8-15 : 1), (16-23 : 2), (24-28+ : 3)
df_prune['WeekofMonth'] = np.where((df_prune['StartDay']<=7), 0, 
                                  np.where((df_prune['StartDay']>8) & (df_prune['StartDay']<=15), 1,
                                          np.where((df_prune['StartDay']>16) & (df_prune['StartDay']<=23), 2, 3))
                                  )

# %%
# (hour:label) --- (1-6 : 0), (7-12 : 1), (13-18 : 2), (19-24 : 3)
df_prune['HourOfDay'] = np.where((df_prune['StartHour']<=7), 0, 
                                  np.where((df_prune['StartHour']>8) & (df_prune['StartHour']<=15), 1,
                                          np.where((df_prune['StartHour']>16) & (df_prune['StartHour']<=23), 2, 3))
                                  )

# %%
# (minute:label) --- (1-15 : 0), (16-30 : 1), (31-45 : 2), (46-60 : 3)
df_prune['MinuteOfHour'] = np.where((df_prune['StartMinute']<=7), 0, 
                                  np.where((df_prune['StartMinute']>8) & (df_prune['StartMinute']<=15), 1,
                                          np.where((df_prune['StartMinute']>16) & (df_prune['StartMinute']<=23), 2, 3))
                                  )

# %%
df_prune.drop(['irs_estimated_population_2015', 
               'Population Estimate (as of July 1) - 2018 - Male; Median age (years)', 
               'Population Estimate (as of July 1) - 2018 - Female; Median age (years)', 
               'StartMonth', 
               'StartDay', 
               'StartHour', 
               'StartMinute',
              'County'], 
              axis = 1,
              inplace=True)

# %%
df_prune.head()
# Out:
#    Severity  LocationLat  LocationLng  ZipCode  Duration  \
# 0         1        47.01      -122.91    98501        80
# 1         2        47.61      -122.33    98104        12
# 2         1        47.96      -122.20    98203        18
# 3         1        47.56      -122.19    98006        22
# 4         1        47.62      -122.33    98101        12
#
#    Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)  \
# 0                                              39.10
# 1                                              36.90
# 2                                              38.00
# 3                                              36.90
# 4                                              36.90
#
#    Density(/sqmi)  DayOfWeek  Season  WeekofMonth  HourOfDay  MinuteOfHour
# 0          335.30          2       3            3          2             3
# 1          870.90          3       3            0          0             3
# 2          334.80          3       3            0          0             3
# 3          870.90          3       3            0          0             0
# 4          870.90          3       3            0          0             2

# %% [markdown]
# ##### Encoding

# %%
df_enc = df.copy()

# %%
def Mon(x):
    return x.split(" ")[0].split('-')[1]
def Day(x):
    return x.split(" ")[0].split('-')[2]
def Hour(x):
    return x.split(" ")[1].split(':')[0]
def Minute(x):
    return x.split(" ")[1].split(':')[1]

df_enc['StartMonth'] = df_enc['StartTime(UTC)'].apply(lambda x: Mon(x)).astype(int)
df_enc['StartDay'] = df_enc['StartTime(UTC)'].apply(lambda x: Day(x)).astype(int)
df_enc['StartHour'] = df_enc['StartTime(UTC)'].apply(lambda x: Hour(x)).astype(int)
df_enc['StartMinute'] = df_enc['StartTime(UTC)'].apply(lambda x: Minute(x)).astype(int)

df_enc['StartTime(UTC)'] = pd.to_datetime(df_enc['StartTime(UTC)'])

def get_dayofweek(x):
    return x.dayofweek
df_enc['DayOfWeek'] = df_enc['StartTime(UTC)'].apply(lambda x: get_dayofweek(x)).astype(int)

df_enc.drop('StartTime(UTC)', inplace=True, axis = 1)

# %%
df_enc.head()
# Out:
#    Severity  LocationLat  LocationLng  ZipCode  Duration  \
# 0         1        47.01      -122.91    98501        80
# 1         2        47.61      -122.33    98104        12
# 2         1        47.96      -122.20    98203        18
# 3         1        47.56      -122.19    98006        22
# 4         1        47.62      -122.33    98101        12
#
#    irs_estimated_population_2015     County  \
# 0                          37370   Thurston
# 1                           8990       King
# 2                          32440  Snohomish
# 3                          39630       King
# 4                          10910       King
#
#    Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)  \
# 0                                              39.10
# 1                                              36.90
# 2                                              38.00
# 3                                              36.90
# 4                                              36.90
#
#    Population Estimate (as of July 1) - 2018 - Male; Median age (years)  \
# 0                                              37.70
# 1                                              36.20
# 2                                              37.20
# 3                                              36.20
# 4                                              36.20
#
#    Population Estimate (as of July 1) - 2018 - Female; Median age (years)  \
# 0                                              40.50
# 1                                              37.70
# 2                                              38.80
# 3                                              37.70
# 4                                              37.70
#
#    Density(/sqmi)  StartMonth  StartDay  StartHour  StartMinute  DayOfWeek
# 0          335.30          11        30         23           35          2
# 1          870.90          12         1          0           52          3
# 2          334.80          12         1          1            8          3
# 3          870.90          12         1          1            2          3
# 4          870.90          12         1          1           19          3

# %%
df_enc['isWeekday'] = np.where(df_enc['DayOfWeek'] <=4, 1, 0)

# %%
df_enc['Mon'] = np.where(df_enc['DayOfWeek'] ==0, 1, 0)
df_enc['Tue'] = np.where(df_enc['DayOfWeek'] ==1, 1, 0)
df_enc['Wed'] = np.where(df_enc['DayOfWeek'] ==2, 1, 0)
df_enc['Thu'] = np.where(df_enc['DayOfWeek'] ==3, 1, 0)
df_enc['Fri'] = np.where(df_enc['DayOfWeek'] ==4, 1, 0)
df_enc['Sat'] = np.where(df_enc['DayOfWeek'] ==5, 1, 0)
df_enc['Sun'] = np.where(df_enc['DayOfWeek'] ==6, 1, 0)

# %%
df_enc['Spring'] = np.where((df_enc['StartMonth'] ==1) | (df_enc['StartMonth'] ==2) | (df_enc['StartMonth'] ==3), 1, 0)
df_enc['Summer'] = np.where((df_enc['StartMonth'] ==4) | (df_enc['StartMonth'] ==5) | (df_enc['StartMonth'] ==6), 1, 0)
df_enc['Autum'] = np.where((df_enc['StartMonth'] ==7) | (df_enc['StartMonth'] ==8) | (df_enc['StartMonth'] ==9), 1, 0)
df_enc['Winter'] = np.where((df_enc['StartMonth'] ==10) | (df_enc['StartMonth'] ==11) | (df_enc['StartMonth'] ==12), 1, 0)

# %%
df_enc['Morning(6-12)'] = np.where((df_enc['StartHour'] >= 6) & (df_enc['StartHour'] < 12), 1, 0)
df_enc['Noon(12-18)'] = np.where((df_enc['StartHour'] >= 12) & (df_enc['StartHour'] < 18), 1, 0)
df_enc['Night(18-24)'] = np.where((df_enc['StartHour'] >= 18) & (df_enc['StartHour'] < 24), 1, 0)
df_enc['midNight(24-6)'] = np.where((df_enc['StartHour'] >= 0) & (df_enc['StartHour'] < 6), 1, 0)

# %%
df_enc['firstHalfHour'] = np.where((df_enc['StartMinute'] <=30), 1, 0)
df_enc['SecondHalfHour'] = np.where((df_enc['StartMinute'] > 30), 1, 0)

# %%
df_enc.drop(['irs_estimated_population_2015', 
               'Population Estimate (as of July 1) - 2018 - Male; Median age (years)', 
               'Population Estimate (as of July 1) - 2018 - Female; Median age (years)', 
               'StartMonth', 
               'StartDay', 
               'StartHour', 
               'StartMinute',
              'County',
            'DayOfWeek'], 
              axis = 1,
              inplace=True)

# %% [markdown]
# ## setting up pipline

# %%
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test

# %%
def boosting_pipeline(X_train, y_train, X_validate, y_validate):
    
    est = HistGradientBoostingRegressor(max_iter =100, 
                                    min_samples_leaf = 24, 
                                    max_leaf_nodes =300, 
                                    l2_regularization = 0.5, 
                                    verbose=0,).fit(X_train, y_train)
    print("Score: ",est.score(X_validate, y_validate))
    
#     result = permutation_importance(est, X_validate, y_validate, n_repeats=10,
#                                 random_state=42, n_jobs=1)
    
    mse = mean_squared_error(y_validate, est.predict(X_validate))
    print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
    
    rms = sqrt(mse)
    print('RMSE:', rms, '\n')
    
#     sorted_idx = result.importances_mean.argsort()

#     fig, ax = plt.subplots(figsize=(15, 10))
#     ax.boxplot(result.importances[sorted_idx].T,
#                vert=False, labels=X_test.columns[sorted_idx])
#     ax.set_title("Permutation Importances (validation set)")
#     fig.tight_layout()
#     plt.show()
    

    
    return est

# %% [markdown]
# ### F.E. piplines

# %%
def explore_fe(df, target):
    ''' 
    A function to do exploratory feature engineering. 
    It's flexible in its purpose, and is currently configured for this project only.

    Inputs:
    df (like X) = Your dataset without the target (y)
    target (like y) = Your target, whatever you are trying to predict ---Binary.

    Output:
    Returns engineered X (dataframe without target) based on the engineering logic.
    '''
    df = df.astype(float)
    df = df.replace({0:1 , 1:2})
    
    for i in range (0, len(df.columns)):
        df[f'{df.columns[i]}^2'] = np.square(df[df.columns[i]])
        df[f'{df.columns[i]}^1/2'] = np.sqrt(df[df.columns[i]])
        df[f'{df.columns[i]} * {df.columns[i+1]}'] = df[df.columns[i]] * df[df.columns[i+1]]
        df[f'{df.columns[i]} / {df.columns[i+1]}'] = df[df.columns[i]] / df[df.columns[i+1]]
#         df[f'{df.columns[i]} + {df.columns[i+1]}'] = df[df.columns[i]] + df[df.columns[i+1]]
#         df[f'{df.columns[i]} - {df.columns[i+1]}'] = df[df.columns[i]] - df[df.columns[i+1]]
        

#     df.fillna(0, inplace = True)
#     df.replace([np.inf, -np.inf], np.nan).dropna(axis=1)
    df[~df.isin([np.nan, np.inf, -np.inf]).any(1)].astype(np.float64)
    
    X,y= df, target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=4444)
    
    ran = RandomForestClassifier(random_state=5)
    ran.fit(X_train, y_train)
    
    print ('Accuracy: ', accuracy_score(y_test, ran.predict(X_test)))
    print("Precision: {:6.4f},   Recall: {:6.4f},   f1: {:6.4f}".format(precision_score(y_test, ran.predict(X_test)), 
                                                 recall_score(y_test, ran.predict(X_test)), f1_score(y_test, ran.predict(X_test))), '\n')
    
    k = list(X.columns)
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(sorted(list(zip(k, ran.feature_importances_)), key=lambda x: x[1], reverse=True))
    
    return df

# %%
def PolynomialFeatures_labeled(input_df,power):
    '''
    Basically this is a cover for the sklearn preprocessing function. 
    The problem with that function is if you give it a labeled dataframe, it ouputs an unlabeled dataframe with potentially
    a whole bunch of unlabeled columns. 

    Inputs:
    input_df = Your labeled pandas dataframe (list of x's not raised to any power) 
    power = what order polynomial you want variables up to. (use the same power as you want entered into pp.PolynomialFeatures(power) directly)

    Output:
    Output: This function relies on the powers_ matrix which is one of the preprocessing function's outputs to create logical labels and 
    outputs a labeled pandas dataframe   
    '''
    poly = PolynomialFeatures(power)
    output_nparray = poly.fit_transform(input_df)
    powers_nparray = poly.powers_

    input_feature_names = list(input_df.columns)
    target_feature_names = ["Constant Term"]
    for feature_distillation in powers_nparray[1:]:
        intermediary_label = ""
        final_label = ""
        for i in range(len(input_feature_names)):
            if feature_distillation[i] == 0:
                continue
            else:
                variable = input_feature_names[i]
                power = feature_distillation[i]
                intermediary_label = "%s^%d" % (variable,power)
                if final_label == "":         #If the final label isn't yet specified
                    final_label = intermediary_label
                else:
                    final_label = final_label + " x " + intermediary_label
        target_feature_names.append(final_label)
    output_df = pd.DataFrame(output_nparray, columns = target_feature_names)
    return output_df

# %% [markdown]
# ### Feature Selection Pipeline

# %%
def feature_selection(X, y, score_to_keep = 5):
    '''
    A function to select features by votes of 6 models who can calculate feature importances.
    Also prints out how many original features there are, how many selected, and a list of selected features.
    Original idea from https://www.kaggle.com/mlwhiz/feature-selection-using-football-data

    Inputs:
    X = Your dataset without the target (y)
    y = Your target, whatever you are trying to predict --- Binary.
    score_to_keep = Pick features that have a 'score_to_keep' amount of votes --- max is 6 votes, default is 5. 
    
    Output:
    Returns selected_X as a dataframe without target(y). 
    '''
    feature_name = list(X.columns)
    num_feats=len(X.columns)
    def cor_selector(X, y,num_feats):
        cor_list = []
        feature_name = X.columns.tolist()
        # calculate the correlation with y for each feature
        for i in X.columns.tolist():
            cor = np.corrcoef(X[i], y)[0, 1]
            cor_list.append(cor)
        # replace NaN with 0
        cor_list = [0 if np.isnan(i) else i for i in cor_list]
        # feature name
        cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
        # feature selection? 0 for not select, 1 for select
        cor_support = [True if i in cor_feature else False for i in feature_name]
        return cor_support, cor_feature
    cor_support, cor_feature = cor_selector(X, y,num_feats)
    
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num_feats)
    chi_selector.fit(X_norm, y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    
    rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_feats, step=10, verbose=5)
    rfe_selector.fit(X_norm, y)
    rfe_support = rfe_selector.get_support()
    rfe_feature = X.loc[:,rfe_support].columns.tolist()
    
    embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), max_features=num_feats)
    embeded_lr_selector.fit(X_norm, y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    
#     embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=num_feats)
#     embeded_rf_selector.fit(X_norm, y)
#     embeded_rf_support = embeded_rf_selector.get_support()
#     embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    
#     lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
#             reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)
#     embeded_lgb_selector = SelectFromModel(lgbc, max_features=num_feats)
#     embeded_lgb_selector.fit(X_norm, y)
#     embeded_lgb_support = embeded_lgb_selector.get_support()
#     embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
    
    feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 'Logistics':embeded_lr_support,
#                                         'Random Forest':embeded_rf_support, 'LightGBM':embeded_lgb_support})
    
    feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
    
    feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
    feature_selection_df.index = range(1, len(feature_selection_df)+1)
    
    
    selected_X = X.copy()
    to_drop = []
    for i in range (0, len(feature_selection_df)):
        if feature_selection_df.Total.values[i] < score_to_keep:
            to_drop.append(feature_selection_df.Feature.values[i])

    selected_X = selected_X.drop(to_drop, axis = 1)
    
    print ("Number of orginal features: ", num_feats)
    print ("Number of selected features: ", len(selected_X.columns), '\n')
    pp = pprint.PrettyPrinter(indent=4)
    print("Selected Features:")
    pp.pprint(list(selected_X.columns))
    
    
    return selected_X

# %% [markdown]
# ## split df

# %% [markdown]
# ##### Binned DF (df_prune)

# %%
X, y = df_prune.drop('Duration',axis=1), df_prune['Duration']
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.1, random_state=13)

# %%
train, validate, test = train_validate_test_split(df_prune)
X_train, y_train = train.drop('Duration',axis=1), train['Duration']
X_validate, y_validate = validate.drop('Duration',axis=1), validate['Duration']
X_test, y_test = test.drop('Duration',axis=1), test['Duration']

# %%
X_validate
# Out:
#         Severity  LocationLat  LocationLng  ZipCode  \
# 284802         1        46.64      -118.87    99343
# 292194         1        47.35      -120.10    98850
# 204862         3        47.19      -122.23    98390
# 274321         1        47.47      -121.77    98045
# 524513         3        47.67      -122.38    98107
# ...          ...          ...          ...      ...
# 49375          2        47.16      -122.29    98373
# 502501         2        47.69      -122.18    98033
# 26232          3        47.57      -122.12    98008
# 297912         2        47.24      -122.42    98404
# 308013         1        47.89      -122.22    98208
#
#         Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)  \
# 284802                                              30.30
# 292194                                              37.60
# 204862                                              36.30
# 274321                                              36.90
# 524513                                              36.90
# ...                                                   ...
# 49375                                               36.30
# 502501                                              36.90
# 26232                                               36.90
# 297912                                              36.30
# 308013                                              38.00
#
#         Density(/sqmi)  DayOfWeek  Season  WeekofMonth  HourOfDay  \
# 284802           66.80          1       0            3          0
# 292194           21.20          3       0            2          1
# 204862          449.90          3       1            1          0
# 274321          870.90          0       0            1          1
# 524513          870.90          2       3            3          1
# ...                ...        ...     ...          ...        ...
# 49375           449.90          5       2            1          2
# 502501          870.90          3       3            1          0
# 26232           870.90          3       3            0          2
# 297912          449.90          5       3            0          2
# 308013          334.80          4       3            2          2
#
#         MinuteOfHour
# 284802             3
# 292194             3
# 204862             3
# 274321             3
# 524513             3
# ...              ...
# 49375              1
# 502501             3
# 26232              3
# 297912             1
# 308013             3
#
# [111499 rows x 11 columns]

# %% [markdown]
# ##### Encoded DF (df_enc)

# %%
X2, y2= df_enc.drop('Duration',axis=1), df_enc['Duration']

# %%
train2, validate2, test2 = train_validate_test_split(df_enc)
X_train2, y_train2 = train2.drop('Duration',axis=1), train2['Duration']
X_validate2, y_validate2 = validate2.drop('Duration',axis=1), validate2['Duration']
X_test2, y_test2 = test2.drop('Duration',axis=1), test2['Duration']

# %%
X_train2
# Out:
#         Severity  LocationLat  LocationLng  ZipCode  \
# 177039         2        47.89      -122.26    98204
# 383550         1        47.44      -122.27    98188
# 376707         2        47.95      -122.10    98290
# 543962         1        47.59      -122.18    98005
# 129708         2        47.44      -122.25    98032
# ...          ...          ...          ...      ...
# 260157         2        47.68      -122.10    98052
# 154723         1        47.53      -122.20    98056
# 100987         1        47.65      -122.32    98105
# 25060          1        47.65      -117.34    99212
# 132215         2        47.27      -121.26    98922
#
#         Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)  \
# 177039                                              38.00
# 383550                                              36.90
# 376707                                              38.00
# 543962                                              36.90
# 129708                                              36.90
# ...                                                   ...
# 260157                                              36.90
# 154723                                              36.90
# 100987                                              36.90
# 25060                                               37.60
# 132215                                              34.00
#
#         Density(/sqmi)  isWeekday  Mon  Tue  Wed  ...  Spring  Summer  Autum  \
# 177039          334.80          1    0    0    1  ...       0       0      1
# 383550          870.90          1    0    1    0  ...       0       0      1
# 376707          334.80          1    0    0    0  ...       0       0      1
# 543962          870.90          1    0    0    0  ...       0       0      1
# 129708          870.90          1    0    0    0  ...       0       0      0
# ...                ...        ...  ...  ...  ...  ...     ...     ...    ...
# 260157          870.90          1    0    0    1  ...       1       0      0
# 154723          870.90          1    1    0    0  ...       0       0      1
# 100987          870.90          1    0    0    0  ...       0       1      0
# 25060           267.80          1    1    0    0  ...       0       0      0
# 132215           17.90          0    0    0    0  ...       0       0      0
#
#         Winter  Morning(6-12)  Noon(12-18)  Night(18-24)  midNight(24-6)  \
# 177039       0              0            0             1               0
# 383550       0              0            1             0               0
# 376707       0              0            0             0               1
# 543962       0              0            1             0               0
# 129708       1              0            0             0               1
# ...        ...            ...          ...           ...             ...
# 260157       0              0            0             1               0
# 154723       0              0            0             1               0
# 100987       0              0            1             0               0
# 25060        1              0            1             0               0
# 132215       1              0            0             1               0
#
#         firstHalfHour  SecondHalfHour
# 177039              0               1
# 383550              1               0
# 376707              1               0
# 543962              0               1
# 129708              1               0
# ...               ...             ...
# 260157              1               0
# 154723              0               1
# 100987              0               1
# 25060               0               1
# 132215              0               1
#
# [334498 rows x 24 columns]

# %%
df_enc_all =df_enc.copy()

# %%
df_enc_all['StartTime(UTC)'] = df['StartTime(UTC)']

# %%
df_enc_all.to_csv('./data/classi_/df_enc_all.csv', index = False)

# %% [markdown]
# ## Start Feature Engineering and testing

# %% [markdown]
# ### Baseline

# %% [markdown]
# ##### Gradient Boosting - binned

# %%
est = boosting_pipeline(X_train, y_train, X_validate, y_validate)
# Out:
# Score:  0.19109010053266895
# The mean squared error (MSE) on test set: 16432.3781
# RMSE: 128.18883772529657

# %%
perm = PermutationImportance(est, random_state=1).fit(X_validate, y_validate)
eli5.show_weights(perm, feature_names = X_validate.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1847
#
#                     &plusmn; 0.0537
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DayOfWeek
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.05%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1458
#
#                     &plusmn; 0.0114
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1082
#
#                     &plusmn; 0.0755
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Season
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1038
#
#                     &plusmn; 0.0226
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HourOfDay
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0958
#
#                     &plusmn; 0.0236
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 WeekofMonth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0840
#
#                     &plusmn; 0.0463
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0830
#
#                     &plusmn; 0.0595
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0650
#
#                     &plusmn; 0.0375
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MinuteOfHour
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0398
#
#                     &plusmn; 0.0182
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ZipCode
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0180
#
#                     &plusmn; 0.0287
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Density(/sqmi)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0038
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# ##### Gradient Boosting - encoded

# %%
est = boosting_pipeline(X_train2, y_train2, X_validate2, y_validate2)
# Out:
# Score:  0.3799130374772476
# The mean squared error (MSE) on test set: 5546.3421
# RMSE: 74.47376795384271

# %%
perm = PermutationImportance(est, random_state=1).fit(X_validate2, y_validate2)
eli5.show_weights(perm, feature_names = X_validate2.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3884
#
#                     &plusmn; 0.0481
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3330
#
#                     &plusmn; 0.2720
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Mon
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3296
#
#                     &plusmn; 0.1779
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2720
#
#                     &plusmn; 0.0448
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Morning(6-12)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2615
#
#                     &plusmn; 0.2348
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Autum
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2158
#
#                     &plusmn; 0.2249
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 midNight(24-6)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1922
#
#                     &plusmn; 0.2310
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1761
#
#                     &plusmn; 0.1563
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 firstHalfHour
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1103
#
#                     &plusmn; 0.0229
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ZipCode
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0481
#
#                     &plusmn; 0.0591
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Spring
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0366
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Noon(12-18)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0202
#
#                     &plusmn; 0.0458
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Density(/sqmi)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0183
#
#                     &plusmn; 0.0242
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 isWeekday
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0129
#
#                     &plusmn; 0.0179
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0051
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Thu
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0047
#
#                     &plusmn; 0.0093
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Tue
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0043
#
#                     &plusmn; 0.0026
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Winter
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0036

# %% [markdown]
# ##### XGboost - binned df vs encoded df

# %%
boost = xgb.XGBRegressor()
boost.fit(X_train,y_train)

boost2 = xgb.XGBRegressor()
boost2.fit(X_train2,y_train2)
# Out:
# [17:29:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:29:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predictions = boost.predict(X_validate)
print( "Score of Binned df: ", r2_score(y_validate,predictions))

predictions = boost2.predict(X_validate2)
print("Score of Encoded df: ", r2_score(y_validate2,predictions))
# Out:
# Score of Binned df:  -0.10659204606946893
# Score of Encoded df:  0.13434382154196634

# %% [markdown]
# ### R1

# %% [markdown]
# ##### 2nd degree poly - binned df

# %%
X_poly_tr = PolynomialFeatures_labeled(X_train, 2)
X_poly_va = PolynomialFeatures_labeled(X_validate, 2)

# %%
X_poly_va
# Out:
#         Constant Term  Severity^1  LocationLat^1  LocationLng^1  ZipCode^1  \
# 0                1.00        3.00          47.88        -122.28   98087.00
# 1                1.00        2.00          47.24        -122.42   98404.00
# 2                1.00        2.00          47.64        -122.32   98102.00
# 3                1.00        3.00          46.56        -122.88   98532.00
# 4                1.00        2.00          47.54        -122.20   98056.00
# ...               ...         ...            ...            ...        ...
# 111494           1.00        1.00          47.81        -122.10   98296.00
# 111495           1.00        2.00          47.48        -122.20   98057.00
# 111496           1.00        2.00          47.72        -122.34   98133.00
# 111497           1.00        3.00          47.60        -122.34   98104.00
# 111498           1.00        3.00          47.44        -122.13   98058.00
#
#         Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)^1  \
# 0                                                   38.00
# 1                                                   36.30
# 2                                                   36.90
# 3                                                   42.90
# 4                                                   36.90
# ...                                                   ...
# 111494                                              38.00
# 111495                                              36.90
# 111496                                              36.90
# 111497                                              36.90
# 111498                                              36.90
#
#         Density(/sqmi)^1  DayOfWeek^1  Season^1  WeekofMonth^1  ...  Season^2  \
# 0                 334.80         5.00      1.00           3.00  ...      1.00
# 1                 449.90         4.00      1.00           2.00  ...      1.00
# 2                 870.90         4.00      3.00           1.00  ...      9.00
# 3                  30.90         3.00      0.00           2.00  ...      0.00
# 4                 870.90         3.00      0.00           0.00  ...      0.00
# ...                  ...          ...       ...            ...  ...       ...
# 111494            334.80         0.00      1.00           3.00  ...      1.00
# 111495            870.90         0.00      3.00           0.00  ...      9.00
# 111496            870.90         5.00      1.00           3.00  ...      1.00
# 111497            870.90         1.00      3.00           2.00  ...      9.00
# 111498            870.90         2.00      0.00           3.00  ...      0.00
#
#         Season^1 x WeekofMonth^1  Season^1 x HourOfDay^1  \
# 0                           3.00                    0.00
# 1                           2.00                    1.00
# 2                           3.00                    6.00
# 3                           0.00                    0.00
# 4                           0.00                    0.00
# ...                          ...                     ...
# 111494                      3.00                    1.00
# 111495                      0.00                    3.00
# 111496                      3.00                    0.00
# 111497                      6.00                    6.00
# 111498                      0.00                    0.00
#
#         Season^1 x MinuteOfHour^1  WeekofMonth^2  WeekofMonth^1 x HourOfDay^1  \
# 0                            2.00           9.00                         0.00
# 1                            1.00           4.00                         2.00
# 2                            9.00           1.00                         2.00
# 3                            0.00           4.00                         2.00
# 4                            0.00           0.00                         0.00
# ...                           ...            ...                          ...
# 111494                       3.00           9.00                         3.00
# 111495                       9.00           0.00                         0.00
# 111496                       2.00           9.00                         0.00
# 111497                       9.00           4.00                         4.00
# 111498                       0.00           9.00                         6.00
#
#         WeekofMonth^1 x MinuteOfHour^1  HourOfDay^2  \
# 0                                 6.00         0.00
# 1                                 2.00         1.00
# 2                                 3.00         4.00
# 3                                 6.00         1.00
# 4                                 0.00         4.00
# ...                                ...          ...
# 111494                            9.00         1.00
# 111495                            0.00         1.00
# 111496                            6.00         0.00
# 111497                            6.00         4.00
# 111498                            9.00         4.00
#
#         HourOfDay^1 x MinuteOfHour^1  MinuteOfHour^2
# 0                               0.00            4.00
# 1                               1.00            1.00
# 2                               6.00            9.00
# 3                               3.00            9.00
# 4                               6.00            9.00
# ...                              ...             ...
# 111494                          3.00            9.00
# 111495                          3.00            9.00
# 111496                          0.00            4.00
# 111497                          6.00            9.00
# 111498                          6.00            9.00
#
# [111499 rows x 78 columns]

# %%
est = boosting_pipeline(X_poly_tr, y_train, X_poly_va, y_validate)
# Out:
# Score:  0.20476869350233817
# The mean squared error (MSE) on test set: 16154.5081
# RMSE: 127.10038589665245

# %%
perm = PermutationImportance(est, random_state=1).fit(X_poly_va, y_validate)
eli5.show_weights(perm, feature_names = X_poly_va.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4933
#
#                     &plusmn; 0.0598
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x HourOfDay^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3354
#
#                     &plusmn; 0.0499
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Density(/sqmi)^1 x HourOfDay^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2995
#
#                     &plusmn; 0.0084
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Density(/sqmi)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2659
#
#                     &plusmn; 0.0050
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2145
#
#                     &plusmn; 0.0314
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Season^1 x HourOfDay^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0809
#
#                     &plusmn; 0.0227
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x Season^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0753
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x HourOfDay^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0723
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x LocationLng^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0697
#
#                     &plusmn; 0.0248
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x Density(/sqmi)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0659
#
#                     &plusmn; 0.0206
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Season^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0634
#
#                     &plusmn; 0.0099
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DayOfWeek^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0613
#
#                     &plusmn; 0.0084
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ZipCode^1 x HourOfDay^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0545
#
#                     &plusmn; 0.0253
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x MinuteOfHour^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0517
#
#                     &plusmn; 0.0292
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0472
#
#                     &plusmn; 0.0065
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x MinuteOfHour^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0358
#
#                     &plusmn; 0.0091
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x ZipCode^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0297
#
#                     &plusmn; 0.0163
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %% [markdown]
# ##### 2nd degree poly - Encoded df

# %%
X_poly_tr2 = PolynomialFeatures_labeled(X_train2, 2)
X_poly_va2 = PolynomialFeatures_labeled(X_validate2, 2)

# %%
X_poly_va2
# Out:
#         Constant Term  Severity^1  LocationLat^1  LocationLng^1  ZipCode^1  \
# 0                1.00        3.00          47.95        -122.30   98203.00
# 1                1.00        3.00          47.69        -122.31   98115.00
# 2                1.00        1.00          47.68        -122.54   98110.00
# 3                1.00        3.00          47.82        -122.32   98036.00
# 4                1.00        3.00          47.38        -122.25   98032.00
# ...               ...         ...            ...            ...        ...
# 111494           1.00        1.00          47.34        -122.25   98001.00
# 111495           1.00        2.00          47.23        -119.28   98837.00
# 111496           1.00        2.00          47.82        -122.32   98036.00
# 111497           1.00        2.00          48.00        -122.11   98258.00
# 111498           1.00        3.00          47.60        -122.33   98104.00
#
#         Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)^1  \
# 0                                                   38.00
# 1                                                   36.90
# 2                                                   38.90
# 3                                                   38.00
# 4                                                   36.90
# ...                                                   ...
# 111494                                              36.90
# 111495                                              33.00
# 111496                                              38.00
# 111497                                              38.00
# 111498                                              36.90
#
#         Density(/sqmi)^1  isWeekday^1  Mon^1  Tue^1  ...  Night(18-24)^2  \
# 0                 334.80         1.00   1.00   0.00  ...            0.00
# 1                 870.90         1.00   0.00   0.00  ...            0.00
# 2                 448.10         1.00   0.00   0.00  ...            0.00
# 3                 334.80         1.00   0.00   1.00  ...            0.00
# 4                 870.90         1.00   0.00   0.00  ...            1.00
# ...                  ...          ...    ...    ...  ...             ...
# 111494            870.90         1.00   0.00   0.00  ...            1.00
# 111495             32.80         0.00   0.00   0.00  ...            0.00
# 111496            334.80         1.00   0.00   0.00  ...            0.00
# 111497            334.80         1.00   0.00   0.00  ...            0.00
# 111498            870.90         0.00   0.00   0.00  ...            0.00
#
#         Night(18-24)^1 x midNight(24-6)^1  Night(18-24)^1 x firstHalfHour^1  \
# 0                                    0.00                              0.00
# 1                                    0.00                              0.00
# 2                                    0.00                              0.00
# 3                                    0.00                              0.00
# 4                                    0.00                              0.00
# ...                                   ...                               ...
# 111494                               0.00                              0.00
# 111495                               0.00                              0.00
# 111496                               0.00                              0.00
# 111497                               0.00                              0.00
# 111498                               0.00                              0.00
#
#         Night(18-24)^1 x SecondHalfHour^1  midNight(24-6)^2  \
# 0                                    0.00              0.00
# 1                                    0.00              1.00
# 2                                    0.00              0.00
# 3                                    0.00              1.00
# 4                                    1.00              0.00
# ...                                   ...               ...
# 111494                               1.00              0.00
# 111495                               0.00              0.00
# 111496                               0.00              1.00
# 111497                               0.00              1.00
# 111498                               0.00              1.00
#
#         midNight(24-6)^1 x firstHalfHour^1  \
# 0                                     0.00
# 1                                     0.00
# 2                                     0.00
# 3                                     0.00
# 4                                     0.00
# ...                                    ...
# 111494                                0.00
# 111495                                0.00
# 111496                                1.00
# 111497                                1.00
# 111498                                1.00
#
#         midNight(24-6)^1 x SecondHalfHour^1  firstHalfHour^2  \
# 0                                      0.00             1.00
# 1                                      1.00             0.00
# 2                                      0.00             0.00
# 3                                      1.00             0.00
# 4                                      0.00             0.00
# ...                                     ...              ...
# 111494                                 0.00             0.00
# 111495                                 0.00             0.00
# 111496                                 0.00             1.00
# 111497                                 0.00             1.00
# 111498                                 0.00             1.00
#
#         firstHalfHour^1 x SecondHalfHour^1  SecondHalfHour^2
# 0                                     0.00              0.00
# 1                                     0.00              1.00
# 2                                     0.00              1.00
# 3                                     0.00              1.00
# 4                                     0.00              1.00
# ...                                    ...               ...
# 111494                                0.00              1.00
# 111495                                0.00              1.00
# 111496                                0.00              0.00
# 111497                                0.00              0.00
# 111498                                0.00              0.00
#
# [111499 rows x 325 columns]

# %%
est2 = boosting_pipeline(X_poly_tr2, y_train2, X_poly_va2, y_validate2)
perm = PermutationImportance(est2, random_state=1).fit(X_poly_va2, y_validate2)
eli5.show_weights(perm, feature_names = X_poly_va2.columns.tolist())
# Out:
# Score:  0.47547439408075054
# The mean squared error (MSE) on test set: 4691.5975
# RMSE: 68.49523723055934
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.0525
#
#                     &plusmn; 0.1642
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x Density(/sqmi)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.9178
#
#                     &plusmn; 0.1103
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x LocationLng^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.05%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.7620
#
#                     &plusmn; 0.0593
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Noon(12-18)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4724
#
#                     &plusmn; 0.0493
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x ZipCode^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3514
#
#                     &plusmn; 0.0273
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x LocationLat^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2833
#
#                     &plusmn; 0.0481
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x isWeekday^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2210
#
#                     &plusmn; 0.0192
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Mon^1 x Morning(6-12)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1950
#
#                     &plusmn; 0.0499
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Mon^1 x Autum^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1832
#
#                     &plusmn; 0.0090
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x LocationLng^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1657
#
#                     &plusmn; 0.0128
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Density(/sqmi)^1 x Noon(12-18)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1524
#
#                     &plusmn; 0.0127
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x Density(/sqmi)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1384
#
#                     &plusmn; 0.0426
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Density(/sqmi)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1045
#
#                     &plusmn; 0.0808
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ZipCode^1 x Mon^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0998
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Mon^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0819
#
#                     &plusmn; 0.0055
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0779
#
#                     &plusmn; 0.0257
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Spring^1 x Morning(6-12)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0657
#
#                     &plusmn; 0.0101
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Density(/sqmi)^1 x Mon^1
#             </td>
#         </tr>

# %% [markdown]
# ##### Running poly transformed features in XGboost

# %%
boost3 = xgb.XGBRegressor()
boost3.fit(X_poly_tr,y_train)

boost4 = xgb.XGBRegressor()
boost4.fit(X_poly_tr2,y_train2)
# Out:
# [18:02:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:03:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predictions = boost3.predict(X_poly_va)
print( "Score of Binned df: ", r2_score(y_validate,predictions))

predictions2 = boost4.predict(X_poly_va2)
print("Score of Encoded df: ", r2_score(y_validate2,predictions2))
# Out:
# Score of Binned df:  -0.08494188758400534
# Score of Encoded df:  0.4154649396838269

# %% [markdown]
# ##### feature selection 1

# %%
perm = PermutationImportance(est2, random_state=1).fit(X_poly_va2, y_validate2)
# eli5.show_weights(perm, feature_names = X_poly_va2.columns.tolist())

# %%
sel = SelectFromModel(perm, threshold=0.05, prefit=True)
X_trans = sel.transform(X_poly_va2)

# %%
sel.get_support()
# Out:
# array([False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#         True, False, False,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True, False,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False,  True, False,  True, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
all_features = X_poly_va2.columns.tolist()

# %%
selected_features = []
for i in range(len(sel.get_support())):
    if sel.get_support()[i] == True:
        selected_features.append(all_features[i])

# %%
selected_features
# Out:
# ['LocationLat^1',
#  'Severity^1 x LocationLat^1',
#  'Severity^1 x LocationLng^1',
#  'Severity^1 x Density(/sqmi)^1',
#  'Severity^1 x isWeekday^1',
#  'LocationLat^1 x LocationLng^1',
#  'LocationLat^1 x ZipCode^1',
#  'LocationLat^1 x Density(/sqmi)^1',
#  'LocationLat^1 x isWeekday^1',
#  'LocationLat^1 x SecondHalfHour^1',
#  'LocationLng^1 x ZipCode^1',
#  'LocationLng^1 x Density(/sqmi)^1',
#  'LocationLng^1 x Mon^1',
#  'LocationLng^1 x Noon(12-18)^1',
#  'ZipCode^1 x Mon^1',
#  'Density(/sqmi)^1 x Mon^1',
#  'Density(/sqmi)^1 x Noon(12-18)^1',
#  'Mon^1 x Autum^1',
#  'Mon^1 x Morning(6-12)^1',
#  'Spring^1 x Morning(6-12)^1']

# %%
X_trans_tr = pd.DataFrame(X_trans, columns = selected_features)

# %%
X_trans_tr
# Out:
#         LocationLat^1  Severity^1 x LocationLat^1  Severity^1 x LocationLng^1  \
# 0               47.95                      143.85                     -366.91
# 1               47.69                      143.06                     -366.94
# 2               47.68                       47.68                     -122.54
# 3               47.82                      143.46                     -366.95
# 4               47.38                      142.14                     -366.74
# ...               ...                         ...                         ...
# 111494          47.34                       47.34                     -122.25
# 111495          47.23                       94.46                     -238.55
# 111496          47.82                       95.63                     -244.64
# 111497          48.00                       96.01                     -244.21
# 111498          47.60                      142.81                     -366.98
#
#         Severity^1 x Density(/sqmi)^1  Severity^1 x isWeekday^1  \
# 0                             1004.40                      3.00
# 1                             2612.70                      3.00
# 2                              448.10                      1.00
# 3                             1004.40                      3.00
# 4                             2612.70                      3.00
# ...                               ...                       ...
# 111494                         870.90                      1.00
# 111495                          65.60                      0.00
# 111496                         669.60                      2.00
# 111497                         669.60                      2.00
# 111498                        2612.70                      0.00
#
#         LocationLat^1 x LocationLng^1  LocationLat^1 x ZipCode^1  \
# 0                            -5864.39                 4708750.77
# 1                            -5832.73                 4678800.68
# 2                            -5842.78                 4677931.99
# 3                            -5849.06                 4687962.21
# 4                            -5792.23                 4644877.43
# ...                               ...                        ...
# 111494                       -5787.37                 4639602.54
# 111495                       -5633.52                 4668111.84
# 111496                       -5848.82                 4687670.85
# 111497                       -5861.47                 4716678.58
# 111498                       -5823.00                 4669991.64
#
#         LocationLat^1 x Density(/sqmi)^1  LocationLat^1 x isWeekday^1  \
# 0                               16053.38                        47.95
# 1                               41530.53                        47.69
# 2                               21365.62                        47.68
# 3                               16009.73                        47.82
# 4                               41264.32                        47.38
# ...                                  ...                          ...
# 111494                          41230.50                        47.34
# 111495                           1549.16                         0.00
# 111496                          16008.73                        47.82
# 111497                          16071.40                        48.00
# 111498                          41456.98                         0.00
#
#         LocationLat^1 x SecondHalfHour^1  LocationLng^1 x ZipCode^1  \
# 0                                   0.00               -12010652.81
# 1                                  47.69               -12000744.80
# 2                                  47.68               -12022436.19
# 3                                  47.82               -11991486.76
# 4                                  47.38               -11984156.23
# ...                                  ...                        ...
# 111494                             47.34               -11980132.54
# 111495                             47.23               -11789023.15
# 111496                              0.00               -11991738.03
# 111497                              0.00               -11997917.09
# 111498                              0.00               -12000623.11
#
#         LocationLng^1 x Density(/sqmi)^1  LocationLng^1 x Mon^1  \
# 0                              -40947.49                -122.30
# 1                             -106522.43                  -0.00
# 2                              -54910.34                  -0.00
# 3                              -40951.79                  -0.00
# 4                             -106465.25                  -0.00
# ...                                  ...                    ...
# 111494                        -106463.17                  -0.00
# 111495                          -3912.30                  -0.00
# 111496                         -40952.65                  -0.00
# 111497                         -40881.18                  -0.00
# 111498                        -106533.30                  -0.00
#
#         LocationLng^1 x Noon(12-18)^1  ZipCode^1 x Mon^1  \
# 0                             -122.30           98203.00
# 1                               -0.00               0.00
# 2                             -122.54               0.00
# 3                               -0.00               0.00
# 4                               -0.00               0.00
# ...                               ...                ...
# 111494                          -0.00               0.00
# 111495                        -119.28               0.00
# 111496                          -0.00               0.00
# 111497                          -0.00               0.00
# 111498                          -0.00               0.00
#
#         Density(/sqmi)^1 x Mon^1  Density(/sqmi)^1 x Noon(12-18)^1  \
# 0                         334.80                            334.80
# 1                           0.00                              0.00
# 2                           0.00                            448.10
# 3                           0.00                              0.00
# 4                           0.00                              0.00
# ...                          ...                               ...
# 111494                      0.00                              0.00
# 111495                      0.00                             32.80
# 111496                      0.00                              0.00
# 111497                      0.00                              0.00
# 111498                      0.00                              0.00
#
#         Mon^1 x Autum^1  Mon^1 x Morning(6-12)^1  Spring^1 x Morning(6-12)^1
# 0                  1.00                     0.00                        0.00
# 1                  0.00                     0.00                        0.00
# 2                  0.00                     0.00                        0.00
# 3                  0.00                     0.00                        0.00
# 4                  0.00                     0.00                        0.00
# ...                 ...                      ...                         ...
# 111494             0.00                     0.00                        0.00
# 111495             0.00                     0.00                        0.00
# 111496             0.00                     0.00                        0.00
# 111497             0.00                     0.00                        0.00
# 111498             0.00                     0.00                        0.00
#
# [111499 rows x 20 columns]

# %%
est2 = boosting_pipeline(X_sel_tr, y_train2, X_sel_val, y_validate2)
perm = PermutationImportance(est2, random_state=1).fit(X_sel_val, y_validate2)
eli5.show_weights(perm, feature_names = X_sel_val.columns.tolist())
# Out:
# Score:  0.4941735641879764
# The mean squared error (MSE) on test set: 4524.3436
# RMSE: 67.26324086708448
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.8515
#
#                     &plusmn; 0.2483
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x Density(/sqmi)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.6844
#
#                     &plusmn; 0.1573
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x LocationLng^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4486
#
#                     &plusmn; 0.0704
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Mon^1 x Autum^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4444
#
#                     &plusmn; 0.0385
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x Density(/sqmi)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4117
#
#                     &plusmn; 0.1136
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x isWeekday^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3380
#
#                     &plusmn; 0.1386
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x SecondHalfHour^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2665
#
#                     &plusmn; 0.1011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Density(/sqmi)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2341
#
#                     &plusmn; 0.0412
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Spring^1 x Morning(6-12)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2290
#
#                     &plusmn; 0.0405
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLat^1 x LocationLng^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1686
#
#                     &plusmn; 0.0578
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Mon^1 x Morning(6-12)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1438
#
#                     &plusmn; 0.0748
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x LocationLat^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1104
#
#                     &plusmn; 0.0155
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x ZipCode^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0949
#
#                     &plusmn; 0.0048
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Noon(12-18)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0903
#
#                     &plusmn; 0.0599
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Density(/sqmi)^1 x Noon(12-18)^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0721
#
#                     &plusmn; 0.0066
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 LocationLng^1 x Mon^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0719
#
#                     &plusmn; 0.0434
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Density(/sqmi)^1 x Mon^1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0694
#
#                     &plusmn; 0.0211
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Severity^1 x isWeekday^1

# %%
X_sel_tr = X_poly_tr2[selected_features]
X_sel_val = pd.DataFrame(X_trans, columns = selected_features)
X_sel_val
# Out:
#         LocationLat^1  Severity^1 x LocationLat^1  Severity^1 x LocationLng^1  \
# 0               47.95                      143.85                     -366.91
# 1               47.69                      143.06                     -366.94
# 2               47.68                       47.68                     -122.54
# 3               47.82                      143.46                     -366.95
# 4               47.38                      142.14                     -366.74
# ...               ...                         ...                         ...
# 111494          47.34                       47.34                     -122.25
# 111495          47.23                       94.46                     -238.55
# 111496          47.82                       95.63                     -244.64
# 111497          48.00                       96.01                     -244.21
# 111498          47.60                      142.81                     -366.98
#
#         Severity^1 x Density(/sqmi)^1  Severity^1 x isWeekday^1  \
# 0                             1004.40                      3.00
# 1                             2612.70                      3.00
# 2                              448.10                      1.00
# 3                             1004.40                      3.00
# 4                             2612.70                      3.00
# ...                               ...                       ...
# 111494                         870.90                      1.00
# 111495                          65.60                      0.00
# 111496                         669.60                      2.00
# 111497                         669.60                      2.00
# 111498                        2612.70                      0.00
#
#         LocationLat^1 x LocationLng^1  LocationLat^1 x ZipCode^1  \
# 0                            -5864.39                 4708750.77
# 1                            -5832.73                 4678800.68
# 2                            -5842.78                 4677931.99
# 3                            -5849.06                 4687962.21
# 4                            -5792.23                 4644877.43
# ...                               ...                        ...
# 111494                       -5787.37                 4639602.54
# 111495                       -5633.52                 4668111.84
# 111496                       -5848.82                 4687670.85
# 111497                       -5861.47                 4716678.58
# 111498                       -5823.00                 4669991.64
#
#         LocationLat^1 x Density(/sqmi)^1  LocationLat^1 x isWeekday^1  \
# 0                               16053.38                        47.95
# 1                               41530.53                        47.69
# 2                               21365.62                        47.68
# 3                               16009.73                        47.82
# 4                               41264.32                        47.38
# ...                                  ...                          ...
# 111494                          41230.50                        47.34
# 111495                           1549.16                         0.00
# 111496                          16008.73                        47.82
# 111497                          16071.40                        48.00
# 111498                          41456.98                         0.00
#
#         LocationLat^1 x SecondHalfHour^1  LocationLng^1 x ZipCode^1  \
# 0                                   0.00               -12010652.81
# 1                                  47.69               -12000744.80
# 2                                  47.68               -12022436.19
# 3                                  47.82               -11991486.76
# 4                                  47.38               -11984156.23
# ...                                  ...                        ...
# 111494                             47.34               -11980132.54
# 111495                             47.23               -11789023.15
# 111496                              0.00               -11991738.03
# 111497                              0.00               -11997917.09
# 111498                              0.00               -12000623.11
#
#         LocationLng^1 x Density(/sqmi)^1  LocationLng^1 x Mon^1  \
# 0                              -40947.49                -122.30
# 1                             -106522.43                  -0.00
# 2                              -54910.34                  -0.00
# 3                              -40951.79                  -0.00
# 4                             -106465.25                  -0.00
# ...                                  ...                    ...
# 111494                        -106463.17                  -0.00
# 111495                          -3912.30                  -0.00
# 111496                         -40952.65                  -0.00
# 111497                         -40881.18                  -0.00
# 111498                        -106533.30                  -0.00
#
#         LocationLng^1 x Noon(12-18)^1  ZipCode^1 x Mon^1  \
# 0                             -122.30           98203.00
# 1                               -0.00               0.00
# 2                             -122.54               0.00
# 3                               -0.00               0.00
# 4                               -0.00               0.00
# ...                               ...                ...
# 111494                          -0.00               0.00
# 111495                        -119.28               0.00
# 111496                          -0.00               0.00
# 111497                          -0.00               0.00
# 111498                          -0.00               0.00
#
#         Density(/sqmi)^1 x Mon^1  Density(/sqmi)^1 x Noon(12-18)^1  \
# 0                         334.80                            334.80
# 1                           0.00                              0.00
# 2                           0.00                            448.10
# 3                           0.00                              0.00
# 4                           0.00                              0.00
# ...                          ...                               ...
# 111494                      0.00                              0.00
# 111495                      0.00                             32.80
# 111496                      0.00                              0.00
# 111497                      0.00                              0.00
# 111498                      0.00                              0.00
#
#         Mon^1 x Autum^1  Mon^1 x Morning(6-12)^1  Spring^1 x Morning(6-12)^1
# 0                  1.00                     0.00                        0.00
# 1                  0.00                     0.00                        0.00
# 2                  0.00                     0.00                        0.00
# 3                  0.00                     0.00                        0.00
# 4                  0.00                     0.00                        0.00
# ...                 ...                      ...                         ...
# 111494             0.00                     0.00                        0.00
# 111495             0.00                     0.00                        0.00
# 111496             0.00                     0.00                        0.00
# 111497             0.00                     0.00                        0.00
# 111498             0.00                     0.00                        0.00
#
# [111499 rows x 20 columns]

# %%
classi_tr = pd.concat([X_sel_tr, y_train2.reset_index(drop=True)], axis = 1)
classi_va = pd.concat([X_sel_val, y_validate2.reset_index(drop=True)], axis = 1)

# %%
classi_tr.to_csv('./data/Engineered/classi_tr.csv', index=False)
classi_va.to_csv('./data/Engineered/classi_va.csv', index=False)

# %%
y_validate
# Out:
# 284802    40
# 292194    42
# 204862    43
# 274321    41
# 524513    70
#           ..
# 49375     39
# 502501    95
# 26232     24
# 297912    41
# 308013    42
# Name: Duration, Length: 111499, dtype: int64

# %% [markdown]
# ##### Run selected features through the model again

# %%
est_sel = boosting_pipeline(X_sel_tr, y_train2, X_sel_val, y_validate2)
# Out:
# Score:  0.49349379075528277
# The mean squared error (MSE) on test set: 4530.4238
# RMSE: 67.3084227806085

# %%
boost_sel = xgb.XGBRegressor()
boost_sel.fit(X_sel_tr,y_train2)
# Out:
# [19:17:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predictions = boost_sel.predict(X_sel_val)
print( "Score of Binned df: ", r2_score(y_validate2,predictions))
# Out:
# Score of Binned df:  0.24167109827603106

# %% [markdown]
# ##### Grid Search

# %% [markdown]
# https://www.kaggle.com/omarito/gridsearchcv-xgbregressor-0-556-lb

# %%
# A parameter grid for XGBoost
# params = {'n_estimators':[100, 200, 300]
#             'min_child_weight':[1,3,6], 
#           'gamma':[i/10.0 for i in range(3,6)],  
#           'subsample':[i/10.0 for i in range(6,11)],
#             'colsample_bytree':[i/10.0 for i in range(6,11)], 
#           'max_depth': [2,10,20],
#          'learning_rate' : [0.01, 0.1, 0.5],
#          'booster' : ['gbtree', 'gblinear '],
#           'reg_alpha' : [0.1, 0.5, 0.9], 
#           'reg_lambda ' : [0.1, 0.5, 0.9],
#           'verbosity' : [1]
#          }

# %%
# A parameter grid for XGBoost
params = {'n_estimators':[100, 200, 300],
            'min_child_weight':[11, 13, 15, 17, 19],
          'gamma':[0.15, 0.2, 0.3, 0.5],  
          'subsample':[0.7, 0.8, 0.9, 1],
            'colsample_bytree':[0.4], 
          'max_depth': [20, 21, 22, 23, 24, 25, 26],
         'learning_rate' : [0.08, 0.1, 0.12],
         'booster' : ['gbtree', 'gblinear'],
          'reg_alpha' : [0, 0.01, 0.05], 
          'reg_lambda ' : [0.05, 0.1, 0.15],
          'verbosity' : [1]
         }

# %%
xgb_grid = xgb.XGBRegressor(n_jobs=1) 

# grid = GridSearchCV(xgb_grid, params)
# grid.fit(X_sel_tr, y_train2)

# # Print the r2 score
# print("Best Estimator: ", grid.best_estimator_)
# print("r2 score: ", r2_score(y_validate2, grid.best_estimator_.predict(X_sel_val)))
# Out:
# [19:47:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:47:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:47:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:48:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:48:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:48:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:48:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:48:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:48:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:49:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:49:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:49:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:49:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:49:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:49:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:50:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:50:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:50:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:50:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:50:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:50:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:51:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:51:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:51:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:51:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:51:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:51:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:52:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:52:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:52:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:52:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:52:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:20:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:20:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:20:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:20:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:20:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:20:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:21:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:21:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:21:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:21:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:21:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:22:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:22:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:22:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:22:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:22:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:22:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:23:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:23:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:23:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:23:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:23:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:23:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:24:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:24:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:24:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:24:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:24:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:24:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:24:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:25:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:25:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:25:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:25:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:25:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:25:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:26:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:26:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:26:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:26:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:26:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:26:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:27:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:27:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:27:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:27:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:27:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:27:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:28:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:28:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:28:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:28:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:28:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:28:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:29:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:29:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:29:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:29:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:29:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:29:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:30:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:30:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:30:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:30:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:30:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:32:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:32:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:32:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:32:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:32:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:32:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:33:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:33:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:33:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:33:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:33:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:33:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:34:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:34:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:34:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:34:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:34:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:34:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:35:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:35:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:35:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:35:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:35:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:35:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:45:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:45:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:45:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:45:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:45:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:45:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:45:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:46:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:46:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:46:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:46:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:46:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:46:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:47:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:47:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:47:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:47:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:47:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:47:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:48:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:48:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:48:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:48:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:48:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:48:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:49:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:49:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:49:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:49:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:49:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:49:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:49:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:51:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:51:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:51:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:51:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:51:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:51:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:52:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:52:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:52:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:52:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:52:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:52:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:52:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:53:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:53:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:53:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:53:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:53:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:53:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:54:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:54:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:54:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:54:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:54:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:54:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:55:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:55:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:55:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:55:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [10:17:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:18:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:19:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:19:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:20:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:23:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:24:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:24:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:25:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:28:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:29:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:30:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:30:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:31:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:33:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:34:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:34:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:35:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:36:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:38:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:39:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:40:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:40:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:41:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:43:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:44:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:44:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:45:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:46:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:54:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:55:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:55:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:58:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:59:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:59:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:01:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:03:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:04:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:05:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:07:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:09:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:11:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:13:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:14:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:16:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:18:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:20:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:22:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:24:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:26:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:30:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:33:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:36:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:39:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:42:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:44:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:46:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:48:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:49:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:51:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:56:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:58:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:00:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-152-026a1d190f3b> in <module>
#       2
#       3 grid = GridSearchCV(xgb_grid, params)
# ----> 4 grid.fit(X_sel_tr, y_train2)
#       5
#       6 # Print the r2 score
#
# F:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# F:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# F:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# F:\Anaconda\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# F:\Anaconda\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# F:\Anaconda\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# F:\Anaconda\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# F:\Anaconda\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# F:\Anaconda\lib\site-packages\joblib\parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# F:\Anaconda\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# F:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# F:\Anaconda\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
#     398         if evals_result:
#
# F:\Anaconda\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# F:\Anaconda\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# F:\Anaconda\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
randgrid = RandomizedSearchCV(estimator = xgb_grid, 
                              param_distributions = params, 
                              n_iter = 100, 
                              n_jobs = 3, 
                              random_state =42,
                              cv =5,
                              verbose = 1)

randgrid.fit(X_sel_tr, y_train2)

print("Best Estimator: ", randgrid.best_estimator_)
print("r2 score: ", r2_score(y_validate2, randgrid.best_estimator_.predict(X_sel_val)))
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed: 72.0min
# [Parallel(n_jobs=3)]: Done 444 tasks      | elapsed: 176.7min
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed: 206.1min finished
# [23:48:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Best Estimator:  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0.15,
#              importance_type='gain', learning_rate=0.08, max_delta_step=0,
#              max_depth=21, min_child_weight=15, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0.01, reg_lambda=1, reg_lambda =0.05, scale_pos_weight=1,
#              seed=None, silent=None, subsample=0.8, verbosity=1)
# r2 score:  0.5223842351893823

# %%
histparams={
    'max_iter' :[100,200, 300, 400], 
    'min_samples_leaf' : [5, 20, 40, 60], 
    'max_leaf_nodes' :[100, 200, 300, 400, 500, 600], 
    'l2_regularization' : [0.01, 0.1, 0.5, 0.9],
    'learning_rate':[0.01, 0.05, 0.1, 0.5, 0.9],
    
    }

# %%
histgb = HistGradientBoostingRegressor()
skboost = RandomizedSearchCV(estimator = histgb, 
                              param_distributions = histparams, 
                              n_iter = 100, 
                              n_jobs = 3, 
                              random_state =42,
                              cv =5,
                              verbose = 1)

skboost.fit(X_sel_tr, y_train2)

print("Best Hist Estimator: ", skboost.best_estimator_)
print("Hist r2 score: ", r2_score(y_validate2, skboost.best_estimator_.predict(X_sel_val)))
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# F:\Anaconda\lib\site-packages\joblib\externals\loky\process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed: 54.9min
# [Parallel(n_jobs=3)]: Done 444 tasks      | elapsed: 124.5min
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed: 149.5min finished
# Best Hist Estimator:  HistGradientBoostingRegressor(l2_regularization=0.5, learning_rate=0.1,
#                               loss='least_squares', max_bins=255,
#                               max_depth=None, max_iter=100, max_leaf_nodes=500,
#                               min_samples_leaf=40, n_iter_no_change=None,
#                               random_state=None, scoring=None, tol=1e-07,
#                               validation_fraction=0.1, verbose=0,
#                               warm_start=False)
# Hist r2 score:  0.41560470282183015

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ##### Best model is:

# %%
best_regressor = randgrid.best_estimator_

# %%
randgrid.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0.15,
#              importance_type='gain', learning_rate=0.08, max_delta_step=0,
#              max_depth=21, min_child_weight=15, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0.01, reg_lambda=1, reg_lambda =0.05, scale_pos_weight=1,
#              seed=None, silent=None, subsample=0.8, verbosity=1)

# %%
X_sel_val.head(2)
# Out:
#    LocationLat^1  Severity^1 x LocationLat^1  Severity^1 x LocationLng^1  \
# 0          47.95                      143.85                     -366.91
# 1          47.69                      143.06                     -366.94
#
#    Severity^1 x Density(/sqmi)^1  Severity^1 x isWeekday^1  \
# 0                        1004.40                      3.00
# 1                        2612.70                      3.00
#
#    LocationLat^1 x LocationLng^1  LocationLat^1 x ZipCode^1  \
# 0                       -5864.39                 4708750.77
# 1                       -5832.73                 4678800.68
#
#    LocationLat^1 x Density(/sqmi)^1  LocationLat^1 x isWeekday^1  \
# 0                          16053.38                        47.95
# 1                          41530.53                        47.69
#
#    LocationLat^1 x SecondHalfHour^1  LocationLng^1 x ZipCode^1  \
# 0                              0.00               -12010652.81
# 1                             47.69               -12000744.80
#
#    LocationLng^1 x Density(/sqmi)^1  LocationLng^1 x Mon^1  \
# 0                         -40947.49                -122.30
# 1                        -106522.43                  -0.00
#
#    LocationLng^1 x Noon(12-18)^1  ZipCode^1 x Mon^1  Density(/sqmi)^1 x Mon^1  \
# 0                        -122.30           98203.00                    334.80
# 1                          -0.00               0.00                      0.00
#
#    Density(/sqmi)^1 x Noon(12-18)^1  Mon^1 x Autum^1  Mon^1 x Morning(6-12)^1  \
# 0                            334.80             1.00                     0.00
# 1                              0.00             0.00                     0.00
#
#    Spring^1 x Morning(6-12)^1
# 0                        0.00
# 1                        0.00

# %% [markdown]
# expected Mon^1 x Autum^1, Density(/sqmi)^1 x Mon^1, Severity^1 x isWeekday^1, LocationLat^1 x LocationLng^1, Density(/sqmi)^1 x Noon(12-18)^1, ZipCode^1 x Mon^1, Severity^1 x Density(/sqmi)^1, Spring^1 x Morning(6-12)^1, LocationLat^1 x Density(/sqmi)^1, LocationLat^1 x SecondHalfHour^1, LocationLng^1 x ZipCode^1, LocationLng^1 x Density(/sqmi)^1, Mon^1 x Morning(6-12)^1, Severity^1 x LocationLat^1, Severity^1 x LocationLng^1, LocationLat^1 x ZipCode^1, LocationLng^1 x Noon(12-18)^1, LocationLng^1 x Mon^1, LocationLat^1, LocationLat^1 x isWeekday^1 in input data

# %%
X_sel_val.columns
# Out:
# Index(['LocationLat^1', 'Severity^1 x LocationLat^1',
#        'Severity^1 x LocationLng^1', 'Severity^1 x Density(/sqmi)^1',
#        'Severity^1 x isWeekday^1', 'LocationLat^1 x LocationLng^1',
#        'LocationLat^1 x ZipCode^1', 'LocationLat^1 x Density(/sqmi)^1',
#        'LocationLat^1 x isWeekday^1', 'LocationLat^1 x SecondHalfHour^1',
#        'LocationLng^1 x ZipCode^1', 'LocationLng^1 x Density(/sqmi)^1',
#        'LocationLng^1 x Mon^1', 'LocationLng^1 x Noon(12-18)^1',
#        'ZipCode^1 x Mon^1', 'Density(/sqmi)^1 x Mon^1',
#        'Density(/sqmi)^1 x Noon(12-18)^1', 'Mon^1 x Autum^1',
#        'Mon^1 x Morning(6-12)^1', 'Spring^1 x Morning(6-12)^1'],
#       dtype='object')

# %%
columns = X_sel_val.columns

# %%
to_pred = [[47.95, 143.85, -366.91, 1004.40, 3.00, -5864.39, 4708750.77, 16053.38, 47.95, 0.00, -12010652.81, -40947.49, -122.30, -122.30, 98203.00, 334.80, 334.80, 1.00, 0.00, 0.00]]

# %%
to_pred_df = pd.DataFrame(to_pred, columns = columns )

# %%
best_regressor.predict(to_pred_df)
# Out:
# array([44.611904], dtype=float32)

# %%
with open("models/best_regressor.pickle", "wb") as pfile:
    pickle.dump(best_regressor, pfile)
